# %% [markdown]
# Imorting all the library require for the experiment

# %% [markdown]
# Imorting all the library require for the experiment

# %%
import pandas as pd 
import glob
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.neighbors import KernelDensity
import math
import seaborn as sns
from itertools import groupby
import sklearn
import plotly.express as px
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# Data importing and preparation about the dataset

# %%
allfiles=glob.glob("EyeT/*.csv")

# %%
# Reading the questionnairy file for getting the epathy result 
questionnaire_ia = pd.read_csv('QuestionnaireIA.csv', encoding='ISO-8859-1')
# renaming the Participant nr to Participant name as in our dataset we are having Participant name
questionnaire_ia.rename(columns={'Participant nr': 'Participant name'}, inplace=True)

# %%
# Columns to check duplicates
columns_to_check = ['Participant name', 'Eye movement type', 'Recording duration', 'Gaze event duration', 'Pupil diameter left', 
                    'Pupil diameter right', 'Gaze point X', 'Gaze point Y']

# %%
# Specify the columns for which we identified which can be featues which we can used 
old_features = ['Gaze point X', 'Gaze point Y', 'Gaze point left X', 'Gaze point left Y', 'Gaze point right X', 
                'Gaze point right Y', 'Gaze direction left X', 'Gaze direction left Y', 'Gaze direction left Z', 
                'Gaze direction right X', 'Gaze direction right Y', 'Gaze direction right Z', 'Pupil diameter left', 
    'Pupil diameter right', 'Fixation point X (MCSnorm)', 'Fixation point Y (MCSnorm)'
    , 'Total Score extended', 'Gaze event duration']

# %% [markdown]
# In this we are preparing the data and focusion on the column which are important for our analysis

# %% [markdown]
# <p> convert the object column and numeriacal string column into the numerical value </p>

# %%
import re
import pandas as pd
# fetch the participant name from the file name
def getParticipantNumber(filename):
    match = re.search(r"participant_(\d+)_trial", filename)
    if match:
        return pd.to_numeric(match.group(1))
    return None

# converting the objet and string clumn into numerical value so that we can do the mathemetical analysis on the given data 
def preprocess_column(col):
    if col.dtype == 'O':
        return pd.to_numeric(col.str.replace(',', '.'), errors='coerce')
    elif col.dtype == 'object':
        return pd.to_numeric(col, errors='coerce')
    return col

data_frames = []

# in this we are mearging all the file into one file and also doing the data type conversion also
for filename in allfiles:
    if filename.endswith(".csv"):
        df = pd.read_csv(filename)
        trial_number = int(filename.split('_trial_')[1].split('.')[0])
        participant_number = getParticipantNumber(filename)
        df['Trial'] = trial_number
        df['Participant name'] = participant_number
        df = df.merge(questionnaire_ia[['Participant name', 'Total Score extended']], on='Participant name', how='left')
        # converting only the column which we are going to use in our analysis
        for col in old_features:
            # calling function to convert the column into proper value
            df[col] = preprocess_column(df[col])
        # drop the exact same column
        df.drop_duplicates(subset=columns_to_check, keep='first', inplace=True)
        # drop the unnamed column
        df.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')
        
        data_frames.append(df)

data = pd.concat(data_frames, ignore_index=True)

# %% [markdown]
#  <ul>
#     <li> Handle null values by filling with 0 (you can use other strategies)</li>
# </ul>

# %%
data =  data.fillna(0)

# %% [markdown]
# <h4> Participants with an even ID-number performed the “foraging for visual information” </h4>
# <h4> participants with an odd ID-number performed “gaze typing” </h4>

# %% [markdown]
# <p> As we have all the data in a single file so we will divide all the data based on the type of analysis and we have 2 type of data oerfrmed
#     <ul>
#     <li> foraging for visual information </l1>
#     <li> gaze typing     </li>
# </p>

# %%
# Define a condition
Group_condition = data['Participant name'] % 2 == 0
# Apply the condition to divide the dataset

# %% [markdown]
# <h1> Defining new feature based on the old feature </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Average Gaze Point X:
# The 'Average Gaze Point X' represents the horizontal position on the screen where a person's gaze tends to be 
# centered on average.
# This value is calculated by averaging the raw gaze coordinates of both eyes combined along the horizontal axis.
# It provides insights into the general area of interest that a person focuses on during a task.

# Calculate Average Gaze Point X
data['Average Gaze Point X'] = (data['Gaze point left X'] + data['Gaze point right X']) / 2


# Difference in Gaze Point X between Eyes:
# The 'Difference in Gaze Point X between Eyes' measures the deviation in horizontal gaze coordinates between 
# the left and right eyes.
# It is calculated as the absolute difference between the left eye's gaze point X and the right eye's gaze point X.
# A higher value indicates that the gaze points of the two eyes are more divergent horizontally.

# Calculate Difference in Gaze Point X between Eyes
data['Difference in Gaze Point X between Eyes'] = abs(data['Gaze point left X'] - data['Gaze point right X'])

# %%
# . Average Gaze Point X and Y
data['Average Gaze Point X'] = (data['Gaze point X'] + data['Gaze point left X'] + data['Gaze point right X']) / 3
data['Average Gaze Point Y'] = (data['Gaze point Y'] + data['Gaze point left Y'] + data['Gaze point right Y']) / 3

#  Difference in Gaze Point X and Y between Eyes
data['Diff Gaze Point X'] = abs(data['Gaze point left X'] - data['Gaze point right X'])
data['Diff Gaze Point Y'] = abs(data['Gaze point left Y'] - data['Gaze point right Y'])

# Calculate the average of Horizontal and Vertical raw gaze coordinates for both eyes combined. Pixels for both eyes
data['Average Gaze point'] = (data['Gaze point X'] + data['Gaze point Y']) / 2


# Calculate the horizontal gaze span
data['Horizontal Gaze Span'] = data['Gaze point right X'] - data['Gaze point left X']

# Calculate the vertical gaze span
data['Vertical Gaze Span'] = data['Gaze point right Y'] - data['Gaze point left Y']



#  Gaze Angle
data['Gaze Angle'] = np.arccos(
    (data['Gaze direction left X'] * data['Gaze direction right X']) +
    (data['Gaze direction left Y'] * data['Gaze direction right Y']) +
    (data['Gaze direction left Z'] * data['Gaze direction right Z'])
)



# Calculate the average pupil diameter for both eyes
data['Average Fixation point DACS'] = (data['Fixation point X'] + data['Fixation point Y']) / 2



# Calculate the average pupil diameter for both eyes
data['Average Fixation point (MCSnorm)'] = (data['Fixation point X (MCSnorm)'] + data['Fixation point Y (MCSnorm)']) / 2



#  Difference in Pupil Diameter between Eyes
data['Diff Pupil Diameter'] = abs(data['Pupil diameter left'] - data['Pupil diameter right'])


# Calculate the average pupil diameter for both eyes pupil Milimeters
data['Average Pupil Diameter'] = (data['Pupil diameter left'] + data['Pupil diameter right']) / 2

# Validity Ratio
data['Validity Ratio Left'] = data['Validity left'].eq('Valid').astype(int)
data['Validity Ratio Right'] = data['Validity right'].eq('Valid').astype(int)
data['Validity Ratio'] = (data['Validity Ratio Left'] + data['Validity Ratio Right']) / 2
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python310\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in arccos
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# making the list of the new features which we get form the old features

# %%
new_features = ['Average Pupil Diameter', 'Average Gaze point', 'Average Fixation point DACS', 
                'Horizontal Gaze Span', 'Vertical Gaze Span', 'Average Fixation point (MCSnorm)', 'Average Gaze Point X', 'Average Gaze Point Y', 
                'Diff Gaze Point X', 'Diff Gaze Point Y', 'Average Pupil Diameter', 'Diff Pupil Diameter', 'Gaze Angle', 'Validity Ratio Left', 
                'Validity Ratio Right', 'Validity Ratio']

# %% [markdown]
# <h4> merging the old and new column so that we can work on our final feature variable </h4>

# %%
features = old_features + new_features
data.sort_values(by='Participant name', ascending=True, inplace=True)

# Create a copy of the original dataset
# copy_data = data

# %% [markdown]
# Correlation Analysis:
# Calculate and visualize the correlation matrix to understand the relationships between numerical variables.

# %%
# Calculate correlation matrix
correlation_matrix = data[new_features+old_features].corr()
# Extract correlation coefficients for the score column

# Plot the correlation matrix
# plt.figure(figsize=(80, 20))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=2)
# plt.title('Correlation Matrix')
# plt.show()

# %%
# Extract correlation coefficients for the score column
score_corr = correlation_matrix['Total Score extended']
print(score_corr)
# Out:
# Average Pupil Diameter              0.002972
# Average Gaze point                  0.005851
# Average Fixation point DACS        -0.009589
# Horizontal Gaze Span                0.028791
# Vertical Gaze Span                  0.036294
# Average Fixation point (MCSnorm)   -0.011881
# Average Gaze Point X                0.009452
# Average Gaze Point Y               -0.001156
# Diff Gaze Point X                  -0.009234
# Diff Gaze Point Y                  -0.015507
# Average Pupil Diameter              0.002972
# Diff Pupil Diameter                -0.002391
# Gaze Angle                         -0.009452
# Validity Ratio Left                -0.013356
# Validity Ratio Right                0.020785
# Validity Ratio                      0.005566
# Gaze point X                        0.008075
# Gaze point Y                       -0.000217
# Gaze point left X                  -0.008338
# Gaze point left Y                  -0.015221
# Gaze point right X                  0.023286
# Gaze point right Y                  0.012461
# Gaze direction left X               0.044485
# Gaze direction left Y              -0.080799
# Gaze direction left Z               0.007200
# Gaze direction right X              0.063788
# Gaze direction right Y             -0.062201
# Gaze direction right Z             -0.026261
# Pupil diameter left                -0.003385
# Pupil diameter right                0.009061
# Fixation point X (MCSnorm)         -0.010834
# Fixation point Y (MCSnorm)         -0.010810
# Total Score extended                1.000000
# Gaze event duration                -0.004877
# Name: Total Score extended, dtype: float64

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data[features+['Participant name']].drop("Total Score extended",axis=1),
    data["Total Score extended"],
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((2936987, 34), (1258709, 34))

# %%
X_train.corr()
# Out:
#                                   Gaze point X  Gaze point Y  \
# Gaze point X                          1.000000     -0.074159
# Gaze point Y                         -0.074159      1.000000
# Gaze point left X                     0.716356     -0.062908
# Gaze point left Y                    -0.095263      0.864390
# Gaze point right X                    0.644185     -0.036291
# Gaze point right Y                   -0.045820      0.858341
# Gaze direction left X                 0.858784     -0.115540
# Gaze direction left Y                -0.140112      0.716781
# Gaze direction left Z                -0.030111     -0.001215
# Gaze direction right X                0.832480     -0.095845
# Gaze direction right Y               -0.112609      0.712032
# Gaze direction right Z               -0.056209     -0.002028
# Pupil diameter left                   0.007075     -0.026927
# Pupil diameter right                  0.024287     -0.019482
# Fixation point X (MCSnorm)            0.284852      0.106621
# Fixation point Y (MCSnorm)           -0.074408      0.514911
# Gaze event duration                  -0.022659     -0.024880
# Average Pupil Diameter                0.016377     -0.024208
# Average Gaze point                    0.690024      0.670622
# Average Fixation point DACS           0.186908      0.213396
# Horizontal Gaze Span                 -0.029978      0.021375
# Vertical Gaze Span                    0.066266     -0.026298
# Average Fixation point (MCSnorm)      0.106858      0.351039
# Average Gaze Point X                  0.912529     -0.066689
# Average Gaze Point Y                 -0.076911      0.970085
# Diff Gaze Point X                     0.233135     -0.011880
# Diff Gaze Point Y                    -0.006744      0.271073
# Average Pupil Diameter                0.016377     -0.024208
# Diff Pupil Diameter                   0.023425      0.034364
# Gaze Angle                           -0.015672     -0.023878
# Validity Ratio Left                   0.031171      0.030068
# Validity Ratio Right                  0.038470      0.030558
# Validity Ratio                        0.050384      0.043828
# Participant name                     -0.088060     -0.015994
#
#                                   Gaze point left X  Gaze point left Y  \
# Gaze point X                               0.716356          -0.095263
# Gaze point Y                              -0.062908           0.864390
# Gaze point left X                          1.000000           0.181653
# Gaze point left Y                          0.181653           1.000000
# Gaze point right X                         0.381848          -0.050776
# Gaze point right Y                        -0.086231           0.708673
# Gaze direction left X                      0.742919          -0.109454
# Gaze direction left Y                     -0.001200           0.765999
# Gaze direction left Z                     -0.641357          -0.394739
# Gaze direction right X                     0.622912          -0.063293
# Gaze direction right Y                    -0.094699           0.588226
# Gaze direction right Z                     0.069442           0.024252
# Pupil diameter left                        0.126853           0.049681
# Pupil diameter right                      -0.055128          -0.063619
# Fixation point X (MCSnorm)                 0.263615           0.113782
# Fixation point Y (MCSnorm)                -0.018512           0.470472
# Gaze event duration                        0.028908          -0.003154
# Average Pupil Diameter                     0.037275          -0.007364
# Average Gaze point                         0.487202           0.556500
# Average Fixation point DACS                0.198370           0.207600
# Horizontal Gaze Span                      -0.520023          -0.205495
# Vertical Gaze Span                        -0.351896          -0.399810
# Average Fixation point (MCSnorm)           0.127744           0.329331
# Average Gaze Point X                       0.820523           0.021282
# Average Gaze Point Y                       0.013566           0.918885
# Diff Gaze Point X                         -0.253246          -0.244263
# Diff Gaze Point Y                         -0.315533          -0.071466
# Average Pupil Diameter                     0.037275          -0.007364
# Diff Pupil Diameter                       -0.235667          -0.156819
# Gaze Angle                                -0.386195          -0.295335
# Validity Ratio Left                        0.644832           0.424214
# Validity Ratio Right                      -0.087121          -0.003741
# Validity Ratio                             0.399031           0.301539
# Participant name                          -0.116522          -0.035099
#
#                                   Gaze point right X  Gaze point right Y  \
# Gaze point X                                0.644185           -0.045820
# Gaze point Y                               -0.036291            0.858341
# Gaze point left X                           0.381848           -0.086231
# Gaze point left Y                          -0.050776            0.708673
# Gaze point right X                          1.000000            0.250714
# Gaze point right Y                          0.250714            1.000000
# Gaze direction left X                       0.469240           -0.104784
# Gaze direction left Y                      -0.053866            0.605848
# Gaze direction left Z                      -0.013572            0.040572
# Gaze direction right X                      0.604257           -0.122957
# Gaze direction right Y                      0.027186            0.756143
# Gaze direction right Z                     -0.725923           -0.395705
# Pupil diameter left                        -0.022829           -0.059558
# Pupil diameter right                        0.151047            0.059538
# Fixation point X (MCSnorm)                  0.264345            0.139837
# Fixation point Y (MCSnorm)                  0.008372            0.498772
# Gaze event duration                         0.034647            0.012637
# Average Pupil Diameter                      0.067041            0.000086
# Average Gaze point                          0.452836            0.588888
# Average Fixation point DACS                 0.186554            0.232019
# Horizontal Gaze Span                        0.590859            0.306978
# Vertical Gaze Span                          0.392765            0.363359
# Average Fixation point (MCSnorm)            0.143534            0.359223
# Average Gaze Point X                        0.811534            0.059012
# Average Gaze Point Y                        0.058950            0.915073
# Diff Gaze Point X                          -0.311683           -0.234338
# Diff Gaze Point Y                          -0.377220           -0.090723
# Average Pupil Diameter                      0.067041            0.000086
# Diff Pupil Diameter                        -0.246558           -0.124379
# Gaze Angle                                 -0.523196           -0.288713
# Validity Ratio Left                         0.006050           -0.018160
# Validity Ratio Right                        0.714356            0.424706
# Validity Ratio                              0.524764            0.296383
# Participant name                           -0.043023            0.001211
#
#                                   Gaze direction left X  \
# Gaze point X                                   0.858784
# Gaze point Y                                  -0.115540
# Gaze point left X                              0.742919
# Gaze point left Y                             -0.109454
# Gaze point right X                             0.469240
# Gaze point right Y                            -0.104784
# Gaze direction left X                          1.000000
# Gaze direction left Y                         -0.186115
# Gaze direction left Z                         -0.033480
# Gaze direction right X                         0.791934
# Gaze direction right Y                        -0.163251
# Gaze direction right Z                         0.048182
# Pupil diameter left                            0.017619
# Pupil diameter right                          -0.004441
# Fixation point X (MCSnorm)                     0.259985
# Fixation point Y (MCSnorm)                    -0.073132
# Gaze event duration                           -0.037567
# Average Pupil Diameter                         0.006858
# Average Gaze point                             0.554947
# Average Fixation point DACS                    0.165324
# Horizontal Gaze Span                          -0.214846
# Vertical Gaze Span                             0.008402
# Average Fixation point (MCSnorm)               0.094538
# Average Gaze Point X                           0.799752
# Average Gaze Point Y                          -0.117597
# Diff Gaze Point X                              0.086218
# Diff Gaze Point Y                             -0.021814
# Average Pupil Diameter                         0.006858
# Diff Pupil Diameter                           -0.001681
# Gaze Angle                                     0.035020
# Validity Ratio Left                            0.030827
# Validity Ratio Right                          -0.068462
# Validity Ratio                                -0.027766
# Participant name                              -0.213608
#
#                                   Gaze direction left Y  \
# Gaze point X                                  -0.140112
# Gaze point Y                                   0.716781
# Gaze point left X                             -0.001200
# Gaze point left Y                              0.765999
# Gaze point right X                            -0.053866
# Gaze point right Y                             0.605848
# Gaze direction left X                         -0.186115
# Gaze direction left Y                          1.000000
# Gaze direction left Z                         -0.135010
# Gaze direction right X                        -0.172549
# Gaze direction right Y                         0.841941
# Gaze direction right Z                        -0.017718
# Pupil diameter left                            0.010448
# Pupil diameter right                          -0.031489
# Fixation point X (MCSnorm)                     0.100634
# Fixation point Y (MCSnorm)                     0.419980
# Gaze event duration                            0.041321
# Average Pupil Diameter                        -0.011013
# Average Gaze point                             0.416008
# Average Fixation point DACS                    0.197328
# Horizontal Gaze Span                          -0.048734
# Vertical Gaze Span                            -0.224402
# Average Fixation point (MCSnorm)               0.293495
# Average Gaze Point X                          -0.070789
# Average Gaze Point Y                           0.745419
# Diff Gaze Point X                             -0.157925
# Diff Gaze Point Y                             -0.006290
# Average Pupil Diameter                        -0.011013
# Diff Pupil Diameter                           -0.080423
# Gaze Angle                                    -0.167603
# Validity Ratio Left                            0.180415
# Validity Ratio Right                           0.055898
# Validity Ratio                                 0.170124
# Participant name                               0.139837
#
#                                   Gaze direction left Z  \
# Gaze point X                                  -0.030111
# Gaze point Y                                  -0.001215
# Gaze point left X                             -0.641357
# Gaze point left Y                             -0.394739
# Gaze point right X                            -0.013572
# Gaze point right Y                             0.040572
# Gaze direction left X                         -0.033480
# Gaze direction left Y                         -0.135010
# Gaze direction left Z                          1.000000
# Gaze direction right X                        -0.084472
# Gaze direction right Y                         0.041272
# Gaze direction right Z                        -0.020493
# Pupil diameter left                           -0.190720
# Pupil diameter right                           0.068006
# Fixation point X (MCSnorm)                    -0.085767
# Fixation point Y (MCSnorm)                    -0.039821
# Gaze event duration                           -0.072754
# Average Pupil Diameter                        -0.063817
# Average Gaze point                            -0.023280
# Average Fixation point DACS                   -0.078069
# Horizontal Gaze Span                           0.547310
# Vertical Gaze Span                             0.573954
# Average Fixation point (MCSnorm)              -0.067834
# Average Gaze Point X                          -0.281783
# Average Gaze Point Y                          -0.129959
# Diff Gaze Point X                              0.550843
# Diff Gaze Point Y                              0.497024
# Average Pupil Diameter                        -0.063817
# Diff Pupil Diameter                            0.384070
# Gaze Angle                                     0.676775
# Validity Ratio Left                           -0.995975
# Validity Ratio Right                           0.035922
# Validity Ratio                                -0.688184
# Participant name                               0.068999
#
#                                   Gaze direction right X  ...  \
# Gaze point X                                    0.832480  ...
# Gaze point Y                                   -0.095845  ...
# Gaze point left X                               0.622912  ...
# Gaze point left Y                              -0.063293  ...
# Gaze point right X                              0.604257  ...
# Gaze point right Y                             -0.122957  ...
# Gaze direction left X                           0.791934  ...
# Gaze direction left Y                          -0.172549  ...
# Gaze direction left Z                          -0.084472  ...
# Gaze direction right X                          1.000000  ...
# Gaze direction right Y                         -0.200581  ...
# Gaze direction right Z                          0.051647  ...
# Pupil diameter left                             0.039729  ...
# Pupil diameter right                            0.008940  ...
# Fixation point X (MCSnorm)                      0.264018  ...
# Fixation point Y (MCSnorm)                     -0.081165  ...
# Gaze event duration                            -0.044152  ...
# Average Pupil Diameter                          0.025369  ...
# Average Gaze point                              0.549675  ...
# Average Fixation point DACS                     0.153851  ...
# Horizontal Gaze Span                            0.014692  ...
# Vertical Gaze Span                             -0.076163  ...
# Average Fixation point (MCSnorm)                0.092052  ...
# Average Gaze Point X                            0.800500  ...
# Average Gaze Point Y                           -0.100454  ...
# Diff Gaze Point X                               0.129296  ...
# Diff Gaze Point Y                              -0.004035  ...
# Average Pupil Diameter                          0.025369  ...
# Diff Pupil Diameter                             0.015245  ...
# Gaze Angle                                     -0.009485  ...
# Validity Ratio Left                             0.078460  ...
# Validity Ratio Right                           -0.077946  ...
# Validity Ratio                                 -0.000511  ...
# Participant name                               -0.182696  ...
#
#                                   Average Gaze Point Y  Diff Gaze Point X  \
# Gaze point X                                 -0.076911           0.233135
# Gaze point Y                                  0.970085          -0.011880
# Gaze point left X                             0.013566          -0.253246
# Gaze point left Y                             0.918885          -0.244263
# Gaze point right X                            0.058950          -0.311683
# Gaze point right Y                            0.915073          -0.234338
# Gaze direction left X                        -0.117597           0.086218
# Gaze direction left Y                         0.745419          -0.157925
# Gaze direction left Z                        -0.129959           0.550843
# Gaze direction right X                       -0.100454           0.129296
# Gaze direction right Y                        0.732857          -0.122995
# Gaze direction right Z                       -0.133978           0.549189
# Pupil diameter left                          -0.012577          -0.083114
# Pupil diameter right                         -0.008586          -0.055483
# Fixation point X (MCSnorm)                    0.128680          -0.086053
# Fixation point Y (MCSnorm)                    0.529179          -0.121975
# Gaze event duration                          -0.005226          -0.106709
# Average Pupil Diameter                       -0.011039          -0.072292
# Average Gaze point                            0.646863           0.164794
# Average Fixation point DACS                   0.233008          -0.105614
# Horizontal Gaze Span                          0.042639          -0.066988
# Vertical Gaze Span                           -0.024556           0.018105
# Average Fixation point (MCSnorm)              0.370793          -0.115064
# Average Gaze Point X                          0.005877          -0.164079
# Average Gaze Point Y                          1.000000          -0.177459
# Diff Gaze Point X                            -0.177459           1.000000
# Diff Gaze Point Y                             0.035172           0.650636
# Average Pupil Diameter                       -0.011039          -0.072292
# Diff Pupil Diameter                          -0.090029           0.493434
# Gaze Angle                                   -0.219795           0.824176
# Validity Ratio Left                           0.158759          -0.543783
# Validity Ratio Right                          0.161761          -0.548521
# Validity Ratio                                0.231715          -0.789634
# Participant name                             -0.017916           0.058294
#
#                                   Diff Gaze Point Y  Average Pupil Diameter  \
# Gaze point X                              -0.006744                0.016377
# Gaze point Y                               0.271073               -0.024208
# Gaze point left X                         -0.315533                0.037275
# Gaze point left Y                         -0.071466               -0.007364
# Gaze point right X                        -0.377220                0.067041
# Gaze point right Y                        -0.090723                0.000086
# Gaze direction left X                     -0.021814                0.006858
# Gaze direction left Y                     -0.006290               -0.011013
# Gaze direction left Z                      0.497024               -0.063817
# Gaze direction right X                    -0.004035                0.025369
# Gaze direction right Y                     0.017516               -0.011382
# Gaze direction right Z                     0.509721               -0.077539
# Pupil diameter left                       -0.061679                0.958165
# Pupil diameter right                      -0.047551                0.958430
# Fixation point X (MCSnorm)                -0.096693                0.062564
# Fixation point Y (MCSnorm)                 0.006365                0.051697
# Gaze event duration                       -0.100495                0.057350
# Average Pupil Diameter                    -0.056981                1.000000
# Average Gaze point                         0.191724               -0.005388
# Average Fixation point DACS               -0.069511                0.068042
# Horizontal Gaze Span                      -0.073184                0.029419
# Vertical Gaze Span                        -0.023493                0.009837
# Average Fixation point (MCSnorm)          -0.047100                0.062461
# Average Gaze Point X                      -0.298528                0.050317
# Average Gaze Point Y                       0.035172               -0.011039
# Diff Gaze Point X                          0.650636               -0.072292
# Diff Gaze Point Y                          1.000000               -0.056981
# Average Pupil Diameter                    -0.056981                1.000000
# Diff Pupil Diameter                        0.490763                0.228487
# Gaze Angle                                 0.757397               -0.097918
# Validity Ratio Left                       -0.491456                0.063583
# Validity Ratio Right                      -0.501745                0.076436
# Validity Ratio                            -0.718025                0.101289
# Participant name                           0.006694               -0.006919
#
#                                   Diff Pupil Diameter  Gaze Angle  \
# Gaze point X                                 0.023425   -0.015672
# Gaze point Y                                 0.034364   -0.023878
# Gaze point left X                           -0.235667   -0.386195
# Gaze point left Y                           -0.156819   -0.295335
# Gaze point right X                          -0.246558   -0.523196
# Gaze point right Y                          -0.124379   -0.288713
# Gaze direction left X                       -0.001681    0.035020
# Gaze direction left Y                       -0.080423   -0.167603
# Gaze direction left Z                        0.384070    0.676775
# Gaze direction right X                       0.015245   -0.009485
# Gaze direction right Y                      -0.048580   -0.123715
# Gaze direction right Z                       0.351320    0.691604
# Pupil diameter left                          0.216308   -0.097250
# Pupil diameter right                         0.221600   -0.090424
# Fixation point X (MCSnorm)                  -0.027376   -0.122616
# Fixation point Y (MCSnorm)                  -0.003068   -0.102411
# Gaze event duration                         -0.025826   -0.103408
# Average Pupil Diameter                       0.228487   -0.097918
# Average Gaze point                           0.042365   -0.028988
# Average Fixation point DACS                 -0.021882   -0.127706
# Horizontal Gaze Span                        -0.022146   -0.146366
# Vertical Gaze Span                           0.045490    0.014902
# Average Fixation point (MCSnorm)            -0.016126   -0.123040
# Average Gaze Point X                        -0.198051   -0.394866
# Average Gaze Point Y                        -0.090029   -0.219795
# Diff Gaze Point X                            0.493434    0.824176
# Diff Gaze Point Y                            0.490763    0.757397
# Average Pupil Diameter                       0.228487   -0.097918
# Diff Pupil Diameter                          1.000000    0.553592
# Gaze Angle                                   0.553592    1.000000
# Validity Ratio Left                         -0.382369   -0.674001
# Validity Ratio Right                        -0.348750   -0.687007
# Validity Ratio                              -0.528323   -0.983950
# Participant name                             0.039753    0.036325
#
#                                   Validity Ratio Left  Validity Ratio Right  \
# Gaze point X                                 0.031171              0.038470
# Gaze point Y                                 0.030068              0.030558
# Gaze point left X                            0.644832             -0.087121
# Gaze point left Y                            0.424214             -0.003741
# Gaze point right X                           0.006050              0.714356
# Gaze point right Y                          -0.018160              0.424706
# Gaze direction left X                        0.030827             -0.068462
# Gaze direction left Y                        0.180415              0.055898
# Gaze direction left Z                       -0.995975              0.035922
# Gaze direction right X                       0.078460             -0.077946
# Gaze direction right Y                      -0.001160              0.177949
# Gaze direction right Z                       0.033714             -0.996301
# Pupil diameter left                          0.191933             -0.051056
# Pupil diameter right                        -0.069664              0.197166
# Fixation point X (MCSnorm)                   0.080774              0.087960
# Fixation point Y (MCSnorm)                   0.055515              0.086720
# Gaze event duration                          0.068617              0.070140
# Average Pupil Diameter                       0.063583              0.076436
# Average Gaze point                           0.045009              0.050795
# Average Fixation point DACS                  0.084366              0.091151
# Horizontal Gaze Span                        -0.557296              0.736245
# Vertical Gaze Span                          -0.583759              0.556696
# Average Fixation point (MCSnorm)             0.074207              0.095861
# Average Gaze Point X                         0.280276              0.290144
# Average Gaze Point Y                         0.158759              0.161761
# Diff Gaze Point X                           -0.543783             -0.548521
# Diff Gaze Point Y                           -0.491456             -0.501745
# Average Pupil Diameter                       0.063583              0.076436
# Diff Pupil Diameter                         -0.382369             -0.348750
# Gaze Angle                                  -0.674001             -0.687007
# Validity Ratio Left                          1.000000             -0.043233
# Validity Ratio Right                        -0.043233              1.000000
# Validity Ratio                               0.685745              0.697514
# Participant name                            -0.054907              0.004937
#
#                                   Validity Ratio  Participant name
# Gaze point X                            0.050384         -0.088060
# Gaze point Y                            0.043828         -0.015994
# Gaze point left X                       0.399031         -0.116522
# Gaze point left Y                       0.301539         -0.035099
# Gaze point right X                      0.524764         -0.043023
# Gaze point right Y                      0.296383          0.001211
# Gaze direction left X                  -0.027766         -0.213608
# Gaze direction left Y                   0.170124          0.139837
# Gaze direction left Z                  -0.688184          0.068999
# Gaze direction right X                 -0.000511         -0.182696
# Gaze direction right Y                  0.128808          0.162075
# Gaze direction right Z                 -0.701647          0.011076
# Pupil diameter left                     0.100467         -0.010442
# Pupil diameter right                    0.093674         -0.002830
# Fixation point X (MCSnorm)              0.122015          0.034946
# Fixation point Y (MCSnorm)              0.102995          0.042674
# Gaze event duration                     0.100313          0.122242
# Average Pupil Diameter                  0.101289         -0.006919
# Average Gaze point                      0.069288         -0.077111
# Average Fixation point DACS             0.126917          0.031742
# Horizontal Gaze Span                    0.136656          0.061953
# Vertical Gaze Span                     -0.013131          0.047921
# Average Fixation point (MCSnorm)        0.123061          0.042796
# Average Gaze Point X                    0.412402         -0.096492
# Average Gaze Point Y                    0.231715         -0.017916
# Diff Gaze Point X                      -0.789634          0.058294
# Diff Gaze Point Y                      -0.718025          0.006694
# Average Pupil Diameter                  0.101289         -0.006919
# Diff Pupil Diameter                    -0.528323          0.039753
# Gaze Angle                             -0.983950          0.036325
# Validity Ratio Left                     0.685745         -0.054907
# Validity Ratio Right                    0.697514          0.004937
# Validity Ratio                          1.000000         -0.035785
# Participant name                       -0.035785          1.000000
#
# [34 rows x 34 columns]

# %% [markdown]
# using Pearson Correlation to find the important feature for out model evalution

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %% [markdown]
# we are finding highly correlated features

# %%
corr_features = correlation(X_train, 0.7)
len(set(corr_features))
# Out:
# 19

# %%
corr_features
# Out:
# {'Average Fixation point (MCSnorm)',
#  'Average Fixation point DACS',
#  'Average Gaze Point X',
#  'Average Gaze Point Y',
#  'Average Pupil Diameter',
#  'Gaze Angle',
#  'Gaze direction left X',
#  'Gaze direction left Y',
#  'Gaze direction right X',
#  'Gaze direction right Y',
#  'Gaze direction right Z',
#  'Gaze point left X',
#  'Gaze point left Y',
#  'Gaze point right Y',
#  'Horizontal Gaze Span',
#  'Pupil diameter right',
#  'Validity Ratio',
#  'Validity Ratio Left',
#  'Validity Ratio Right'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#          Gaze point X  Gaze point Y  Gaze point right X  \
# 3862628        1213.0         482.0              1213.0
# 2678020         957.0         536.0              1136.0
# 3924916         955.0         692.0               976.0
# 2013364         678.0         199.0               769.0
# 3306688        1053.0         384.0              1059.0
# ...               ...           ...                 ...
# 1872749         821.0         432.0               905.0
# 4126033        1067.0         120.0              1136.0
# 1326518         998.0         108.0              1075.0
# 524315         1213.0         706.0                 0.0
# 1377093         910.0         492.0              1045.0
#
#          Gaze direction left Z  Pupil diameter left  \
# 3862628                0.00000                 0.00
# 2678020               -0.99924                 0.00
# 3924916               -0.97453                 0.00
# 2013364               -0.98954                 3.01
# 3306688               -0.99762                 3.52
# ...                        ...                  ...
# 1872749               -0.97146                 0.00
# 4126033               -0.99629                 4.06
# 1326518               -0.99420                 0.00
# 524315                -0.94611                 3.61
# 1377093               -0.95718                 0.00
#
#          Fixation point X (MCSnorm)  Fixation point Y (MCSnorm)  \
# 3862628                      0.6326                      0.4550
# 2678020                      0.0000                      0.0000
# 3924916                      0.5010                      0.6387
# 2013364                      0.3116                      0.1891
# 3306688                      0.0000                      0.0000
# ...                             ...                         ...
# 1872749                      0.4090                      0.4009
# 4126033                      0.5904                      0.1019
# 1326518                      0.5300                      0.1046
# 524315                       0.0000                      0.0000
# 1377093                      0.0000                      0.0000
#
#          Gaze event duration  Average Gaze point  Vertical Gaze Span  \
# 3862628                808.0               847.5               482.0
# 2678020                 17.0               746.5               -79.0
# 3924916                425.0               823.5                 8.0
# 2013364                183.0               438.5               -73.0
# 3306688                  8.0               718.5                65.0
# ...                      ...                 ...                 ...
# 1872749                192.0               626.5               -20.0
# 4126033                108.0               593.5               -49.0
# 1326518                608.0               553.0               -42.0
# 524315                  58.0               959.5              -706.0
# 1377093                 67.0               701.0               -75.0
#
#          Diff Gaze Point X  Diff Gaze Point Y  Diff Pupil Diameter  \
# 3862628             1213.0              482.0                 3.33
# 2678020              357.0               79.0                 0.00
# 3924916               43.0                8.0                 0.00
# 2013364              182.0               73.0                 0.00
# 3306688               12.0               65.0                 0.18
# ...                    ...                ...                  ...
# 1872749              168.0               20.0                 0.00
# 4126033              138.0               49.0                 1.01
# 1326518              155.0               42.0                 0.00
# 524315              1213.0              706.0                 3.61
# 1377093              271.0               75.0                 0.00
#
#          Participant name
# 3862628                12
# 2678020                 7
# 3924916                20
# 2013364                47
# 3306688                10
# ...                   ...
# 1872749                43
# 4126033                50
# 1326518                31
# 524315                 15
# 1377093                33
#
# [1258709 rows x 14 columns]

# %%
corr_features_score = list(corr_features)
print(corr_features_score)
# Out:
# ['Gaze direction left Y', 'Gaze direction right Z', 'Gaze direction left X', 'Average Pupil Diameter', 'Average Gaze Point Y', 'Gaze direction right Y', 'Gaze direction right X', 'Gaze point left Y', 'Average Fixation point (MCSnorm)', 'Gaze Angle', 'Validity Ratio Right', 'Gaze point right Y', 'Pupil diameter right', 'Horizontal Gaze Span', 'Validity Ratio Left', 'Average Fixation point DACS', 'Validity Ratio', 'Average Gaze Point X', 'Gaze point left X']

# %% [markdown]
# creating the final dataset with all the important correlation feature which we get from the pearson analysis

# %%
final_data = data[corr_features_score + ['Participant name', 'Total Score extended']]
final_data = final_data.fillna(0)

# %% [markdown]
# plotting the correlation matrix

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the midpoint
midpoint = len(corr_features_score) // 2

# Divide the list into two equal parts
first_half = corr_features_score[:midpoint]
second_half = corr_features_score[midpoint:]

# Calculate correlation matrix
correlation_matrix = data[first_half + ['Total Score extended']].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap between Gaze Patterns, Pupil Dilation, and Empathy Score")
plt.show()



# Calculate correlation matrix
correlation_matrix = data[second_half + ['Total Score extended']].corr()

# Create a heatmap to visualize the correlations
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap between Gaze Patterns, Pupil Dilation, and Empathy Score")
plt.show()

# %%
# data['Total Score extended']


# Define a condition
Group_condition = final_data['Participant name'] % 2 == 0
# Apply the condition to divide the dataset

# Participants with an even ID-number performed the “foraging for visual information”,                                            
# visual_information = final_data[Group_condition]


# # participants with an odd ID-number performed “gaze typing” 
# gaze_typing = copy_data_final[~Group_condition]

# RandomForestRegressorModel(visual_information, visual_information['Total Score extended'])
# RandomForestRegressorGroupKfold(final_data, final_data['Total Score extended'])

# %% [markdown]
# Model Selection and Training:</br>
# For this demonstration, i am using regression models:</br>
# 1: Linear Regression </br>
# 2: Desicion tree.</br>

# %% [markdown]
# <h4> LinearRegression with train and test </h4>

# %%
def LinearRegression(final_data):
    import pandas as pd
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler
    from sklearn.linear_model import LinearRegression
    from sklearn.pipeline import make_pipeline
    from sklearn.metrics import mean_squared_error, r2_score
  
    # Created training and test split
    
    X_train, X_test, y_train, y_test = train_test_split(final_data.drop(columns=['Total Score extended']), final_data['Total Score extended'], test_size=0.3, random_state=42)
    
    # Fit a pipeline using Training dataset and related labels
    
    pipeline = make_pipeline(StandardScaler(), LinearRegression())
    pipeline.fit(X_train, y_train)
    
    # Calculate the predicted value for training and test dataset
    
    y_train_pred = pipeline.predict(X_train)
    y_test_pred = pipeline.predict(X_test)
    
    # Mean Squared Error
    
    print('MSE train: %.3f, test: %.3f' % (mean_squared_error(y_train, y_train_pred),
                    mean_squared_error(y_test, y_test_pred)))
    
    # R-Squared
    
    print('R^2 train: %.3f, test: %.3f' % (r2_score(y_train, y_train_pred),
                    r2_score(y_test, y_test_pred)))

# %%
print("LinearRegression  Regressor:")

print("final_data")
print(LinearRegression(final_data))
print("visual_information")
print(LinearRegression(final_data[Group_condition]))
print("gaze_typing")
print(LinearRegression(final_data[~Group_condition]))

# LinearRegression  Regressor:
# final_data
# MSE train: 109.703, test: 109.443
# R^2 train: 0.039, test: 0.040
# None
# visual_information
# MSE train: 119.654, test: 119.344
# R^2 train: 0.050, test: 0.050
# None
# gaze_typing
# MSE train: 102.624, test: 102.854
# R^2 train: 0.069, test: 0.068
# None
# Out:
# LinearRegression  Regressor:
# final_data
# MSE train: 109.703, test: 109.443
# R^2 train: 0.039, test: 0.040
# None
# visual_information
# MSE train: 119.654, test: 119.345
# R^2 train: 0.050, test: 0.050
# None
# gaze_typing
# MSE train: 102.623, test: 102.854
# R^2 train: 0.069, test: 0.068
# None

# %% [markdown]
# <h4> LinearRegression with train and test </br> KFold </br> to find the </br> R^2 Score </br> mean absolute error</h4>

# %%
def LinearRegressionKfoldGroupKfold(final_data):  
    from sklearn.model_selection import KFold
    from sklearn.linear_model import LinearRegression
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.preprocessing import MinMaxScaler
    import numpy as np


    # Assuming your data is in the variable 'data'
    X = final_data.drop(columns=['Total Score extended'])  # Features
    y = final_data['Total Score extended']  # Target variable

    # Initialize the MinMaxScaler
    scaler = MinMaxScaler()

    # Initialize the Linear Regression model
    model = LinearRegression()

    # Initialize KFold with 5 folds
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    # Initialize lists to store evaluation metrics
    mse_scores = []
    r2_scores = []

    # Loop through each fold
    for train_index, test_index in kf.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # Scale the features
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)
        
        # Train the model
        model.fit(X_train_scaled, y_train)
        
        # Predict on the test set
        y_pred = model.predict(X_test_scaled)
        
        # Calculate metrics
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        
        # Append metrics to lists
        mse_scores.append(mse)
        r2_scores.append(r2)

    # Calculate mean scores
    mean_mse = sum(mse_scores) / len(mse_scores)
    mean_r2 = sum(r2_scores) / len(r2_scores)

    print(f"Mean Squared Error (MSE): {mean_mse}")
    print(f"Mean R^2 Score: {mean_r2}")

# %%
print("LinearRegression Regressor:")

print("final_data")
print(LinearRegressionKfoldGroupKfold(final_data))
print("visual_information")
print(LinearRegressionKfoldGroupKfold(final_data[Group_condition]))
print("gaze_typing")
print(LinearRegressionKfoldGroupKfold(final_data[~Group_condition]))
# LinearRegression Regressor:
# final_data
# Mean MAE: 9.860896545675676
# R^2 score: -0.31376067792333284

# LinearRegression Regressor:
# final_data
# Mean MSE: 124.66928029893816
# Mean R2 Score: -0.24748921007791563
# None

# LinearRegression Regressor:
# final_data
# Mean Squared Error (MSE): 109.62632960472963
# Mean R^2 Score: 0.039425863737394165
# None
# visual_information
# Mean Squared Error (MSE): 119.56749601798958
# Mean R^2 Score: 0.05035007889783594
# None
# gaze_typing
# Mean Squared Error (MSE): 102.69401777675239
# Mean R^2 Score: 0.06879969805080514
# None
# Out:
# LinearRegression Regressor:
# final_data
# Mean Squared Error (MSE): 109.62630356975626
# Mean R^2 Score: 0.039426092160419146
# None
# visual_information
# Mean Squared Error (MSE): 119.56750560924175
# Mean R^2 Score: 0.05035001171761364
# None
# gaze_typing
# Mean Squared Error (MSE): 102.6940900326377
# Mean R^2 Score: 0.06879904293519896
# None

# %% [markdown]
# <h4> Decision Tress Regressor </br> to find the </br> R^2 Score </br> mean absolute error</h4>

# %%
def DecisionTreeRegressor(final_data):
    import pandas as pd
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.metrics import mean_squared_error, r2_score
    # Define the features (X) and target (y)
    # X = final_data.drop(columns=['Total Score extended'])

    # y = final_data['Total Score extended']  # Assuming 'Empathy_Score' is the target column

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(final_data.drop(columns=['Total Score extended']), final_data['Total Score extended'], test_size=0.2, random_state=42)

    # Apply MinMax scaling to features
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Initialize Decision Tree model
    model = DecisionTreeRegressor(random_state=42)

    # Train the model
    model.fit(X_train_scaled, y_train)

    # Predict on the test set
    y_pred = model.predict(X_test_scaled)

    # Calculate Mean Squared Error (MSE)
    mse = mean_squared_error(y_test, y_pred)
    print("Mean Squared Error:", mse)

    # Calculate R-squared (R2) score
    r2 = r2_score(y_test, y_pred)
    print("R-squared:", r2)

# %%
print("Decision Tree  Regressor:")

print("final_data")
print(DecisionTreeRegressor(final_data))

print("visual_information")
print(DecisionTreeRegressor(final_data[Group_condition]))

print("gaze_typing")
print(DecisionTreeRegressor(final_data[~Group_condition]))

# 2 min
# Decision Tree  Regressor:
# final_data
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# visual_information
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# gaze_typing
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# Out:
# Decision Tree  Regressor:
# final_data
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# visual_information
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# gaze_typing
# Mean Squared Error: 0.0
# R-squared: 1.0
# None

# %% [markdown]
# Decision Tree  Regressor:
# final_data
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# visual_information
# Mean Squared Error: 0.0
# R-squared: 1.0
# None
# gaze_typing
# Mean Squared Error: 0.0
# R-squared: 1.0
# None

# %% [markdown]
# <h3> Decision Tress Regressor  K fold  </br> to find the </br> R^2 Score </br> mean absolute error</h3>

# %%
def DecisionTreeRegressorKfoldGroup(final_data):
    
    from sklearn.model_selection import KFold
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.preprocessing import MinMaxScaler
    import numpy as np

    # Load and preprocess data
    # X, y = load_and_preprocess_data()  # Replace with your data loading/preprocessing code
    X =  final_data.drop(columns=['Total Score extended'])
    y = final_data['Total Score extended']

    # Apply MinMaxScaler
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    # Reset indices to avoid alignment issues
    X = pd.DataFrame(X_scaled, columns=X.columns)
    y = y.reset_index(drop=True)

    # Initialize model and cross-validation
    model = DecisionTreeRegressor(random_state=42)
    kf = KFold(n_splits=5, shuffle=True, random_state=42)  # Adjust number of splits as needed

    mse_scores = []
    r2_scores = []

    # Perform k-fold cross-validation
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        
        mse_scores.append(mse)
        r2_scores.append(r2)

    # Calculate average scores
    avg_mse = np.mean(mse_scores)
    avg_r2 = np.mean(r2_scores)

    print("Average MSE:", avg_mse)
    print("Average R2 Score:", avg_r2)

# %%
print("Decision Tree  Regressor:")

print("final_data")
print( DecisionTreeRegressorKfoldGroup(final_data))
# Out:
# Decision Tree  Regressor:
# final_data
# Average MSE: 0.0
# Average R2 Score: 1.0
# None

# %%
print("visual_information")
visual_information = final_data[Group_condition]
print(visual_information.shape)
print(DecisionTreeRegressorKfoldGroup(visual_information))

print("gaze_typing")
gaze_typing = final_data[~Group_condition]
print(gaze_typing.shape)

print(DecisionTreeRegressorKfoldGroup(gaze_typing))
# Out:
# visual_information
# (910614, 21)
# Average MSE: 7.02825578458396e-05
# Average R2 Score: 0.9999994407345592
# None
# gaze_typing
# (3285082, 21)
# Average MSE: 0.0
# Average R2 Score: 1.0
# None

# %%
print("visual_information")
visual_information = final_data[Group_condition]
print(visual_information.shape)
print(DecisionTreeRegressorKfoldGroup(visual_information))

print("gaze_typing")
gaze_typing = final_data[~Group_condition]
print(gaze_typing.shape)

print(DecisionTreeRegressorKfoldGroup(gaze_typing))
# Out:
# visual_information
# (910614, 21)
# Average MSE: 7.02825578458396e-05
# Average R2 Score: 0.9999994407345592
# None
# gaze_typing
# (3285082, 21)
# Average MSE: 0.0
# Average R2 Score: 1.0
# None
